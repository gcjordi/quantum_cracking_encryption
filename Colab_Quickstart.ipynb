# %% [markdown]
# # Quantum Cryptography Lab v2.0 — Colab Quickstart

# %% [markdown]
# This notebook uses the provider-neutral NumPy backend. No IBM account, token or quantum cloud service is required.

# %%
# Portable bootstrap: works from a repo checkout; in Colab it can install from GitHub.
import sys, pathlib, importlib.util
root = pathlib.Path.cwd()
if (root / 'quantum_crypto_lab').exists():
    sys.path.insert(0, str(root))
elif (root.parent / 'quantum_crypto_lab').exists():
    sys.path.insert(0, str(root.parent))
elif importlib.util.find_spec('quantum_crypto_lab') is None:
    # %pip install -q 'git+https://github.com/gcjordi/quantum_cracking_encryption.git'

# %%
from quantum_crypto_lab import factor_integer
for n in (15, 21, 35):
    result = factor_integer(n)
    print(f'N={n} -> factors={result.factors} via {result.backend_name}')

# %% [markdown]
# These are deliberately tiny educational composites. Statevector simulation does not scale to RSA-2048.
