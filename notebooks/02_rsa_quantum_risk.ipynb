# %% [markdown]
# # RSA Quantum Risk: Toy Demo vs Real Systems

# %%
# Portable bootstrap: works from a repo checkout; in Colab it can install from GitHub.
import sys, pathlib, importlib.util
root = pathlib.Path.cwd()
if (root / 'quantum_crypto_lab').exists():
    sys.path.insert(0, str(root))
elif (root.parent / 'quantum_crypto_lab').exists():
    sys.path.insert(0, str(root.parent))
elif importlib.util.find_spec('quantum_crypto_lab') is None:
    # %pip install -q 'git+https://github.com/gcjordi/quantum_cracking_encryption.git'

# %%
from quantum_crypto_lab.resources import rsa2048_research_context
for item in rsa2048_research_context():
    print(item.year, item.physical_qubits, item.runtime, item.source)

# %% [markdown]
# The estimates are dated research scenarios, not forecasts. The simulator in this repository intentionally cannot approach cryptographic key sizes.
